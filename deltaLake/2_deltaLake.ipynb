# %%
data = [(1,20000,"harish"),(2,30000,"pooja"),(3,40000,"raji")]
df = spark.createDataFrame(data,['id','salary','name'])

display(df)

# %%
df.write.format("delta")\
    .mode("append")\
    .save("/Volumes/deltalake/default/deltavol/sink/")

# %%
df_json = spark.read.format("json")\
    .load("/Volumes/deltalake/default/deltavol/sink/_delta_log/00000000000000000001.json")
display(df_json)
