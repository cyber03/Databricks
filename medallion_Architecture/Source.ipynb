-- %%
CREATE TABLE datamodeling.default.source_data(
  order_id INT PRIMARY KEY,
  order_date DATE,
  customer_id INT,
  customer_name VARCHAR(100),
  customer_email VARCHAR(100),
  product_id INT,
  product_name VARCHAR(100),
  product_category VARCHAR(100),
  quantity INT,
  unit_price DECIMAL(10,2),
  payment_type VARCHAR(50),
  country VARCHAR(50),
  last_update DATE
)

-- %%
--Initial load into the table
INSERT INTO datamodeling.default.source_data (
  order_id, order_date, customer_id, customer_name, customer_email,
  product_id, product_name, product_category, quantity, unit_price,
  payment_type, country, last_update
)
VALUES
(1001, '2025-09-01', 501, 'Arjun Mehta', 'arjun.mehta@example.com', 301, 'Wireless Mouse', 'Electronics', 2, 850.00, 'Credit Card', 'India', '2025-09-05'),
(1002, '2025-09-03', 502, 'Sophia Williams', 'sophia.williams@example.com', 302, 'Noise Cancelling Headphones', 'Electronics', 1, 4999.00, 'UPI', 'USA', '2025-09-04'),
(1003, '2025-09-04', 503, 'Rahul Iyer', 'rahul.iyer@example.com', 303, 'Gaming Keyboard', 'Electronics', 1, 3200.00, 'Net Banking', 'India', '2025-09-06'),
(1004, '2025-09-06', 504, 'Emma Brown', 'emma.brown@example.com', 304, 'Office Chair', 'Furniture', 1, 8999.00, 'Credit Card', 'UK', '2025-09-07'),
(1005, '2025-09-07', 505, 'Liam Johnson', 'liam.johnson@example.com', 305, 'Wooden Study Table', 'Furniture', 1, 12500.00, 'Debit Card', 'Canada', '2025-09-09'),
(1006, '2025-09-10', 506, 'Priya Sharma', 'priya.sharma@example.com', 306, 'Ceramic Mug Set', 'Home Decor', 4, 600.00, 'UPI', 'India', '2025-09-11'),
(1007, '2025-09-11', 507, 'Noah Davis', 'noah.davis@example.com', 307, 'Fitness Tracker', 'Wearables', 1, 5999.00, 'PayPal', 'Australia', '2025-09-12'),
(1008, '2025-09-13', 508, 'Olivia Patel', 'olivia.patel@example.com', 308, 'Bluetooth Speaker', 'Electronics', 2, 2750.00, 'Credit Card', 'India', '2025-09-14'),
(1009, '2025-09-14', 509, 'Ethan Martin', 'ethan.martin@example.com', 309, 'LED Desk Lamp', 'Home Decor', 1, 1300.00, 'Debit Card', 'USA', '2025-09-15'),
(1010, '2025-09-15', 510, 'Ava Thomas', 'ava.thomas@example.com', 310, 'Smartphone Stand', 'Accessories', 3, 450.00, 'Credit Card', 'UK', '2025-09-16');

-- %%
select * from datamodeling.default.source_data
